# %% [markdown]
# # Вокодер - реализация принципиальной схемы
#
# Принципильная схема вокодера выглядит так:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile
from IPython import display

# %% [markdown]
# Загрузим исходный файл для теста

# %%
filepath = r"test_sample.wav"
display.Audio(filepath)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate, voice = wavfile.read(filepath)
voice = voice[:, 0]
time = np.linspace(0, voice.shape[0] / sample_rate, voice.shape[0])

plt.figure(figsize = (16, 3), dpi = 200)
plt.plot(time, voice)
plt.xlim(0.5, 2)
plt.xlabel("Время [c]", fontsize = 16)
plt.ylabel("Амплитуда [отн. ед]", fontsize = 16)
plt.title("Голос - исходная форма волны", fontsize = 16)
plt.grid(ls = ':')

# %% [markdown]
# ### Стадия один - цепочка фильтров узкой полосы

# %%
center_freqs = np.arange(20, 1000, 100)
bp_filters = [signal.butter(2, Wn = [freq-20, freq+20], btype = 'band', analog = True, fs = 1000, output = 'sos') for freq in center_freqs]
filtered_signals = [signal.sosfilt(bp_filters[i], voice) for i in range(len(center_freqs))]
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/vladimir/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#   File "/tmp/ipykernel_5853/740990578.py", line 2, in <module>
#     bp_filters = [signal.butter(2, Wn = [freq-20, freq+20], btype = 'band', analog = True, fs = 1000, output = 'sos') for freq in center_freqs]
#   File "/tmp/ipykernel_5853/740990578.py", line 2, in <listcomp>
#     bp_filters = [signal.butter(2, Wn = [freq-20, freq+20], btype = 'band', analog = True, fs = 1000, output = 'sos') for freq in center_freqs]
#   File "/home/vladimir/.local/lib/python3.10/site-packages/scipy/signal/_filter_design.py", line 3094, in butter
#     return iirfilter(N, Wn, btype=btype, analog=analog,
#   File "/home/vladimir/.local/lib/python3.10/site-packages/scipy/signal/_filter_design.py", line 2499, in iirfilter
#     raise ValueError("fs cannot be specified for an analog filter")
# ValueError: fs cannot be specified for an analog filter
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/inspect.py", line 991, in findsource
#     line = lines[lnum]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vladimir/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     """
#   File "/home/vladimir/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1288, in structured_traceback
#     """Convert a structured traceback (a list) to a string."""
#   File "/home/vladimir/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1177, in structured_traceback
#     else:
#   File "/home/vladimir/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1030, in structured_traceback
#     structured_traceback_parts += formatted_exception
#   File "/home/vladimir/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 935, in format_exception_as_a_whole
#     value = text_repr(getattr(evalue, name))
#   File "/home/vladimir/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1003, in get_records
#     colorsnormal = colors.Normal  # used a lot
#   File "/usr/lib/python3.10/inspect.py", line 1129, in getsourcelines
#     lines, lnum = findsource(object)
#   File "/usr/lib/python3.10/inspect.py", line 993, in findsource
#     raise OSError('lineno is out of bounds')
# OSError: lineno is out of bounds
